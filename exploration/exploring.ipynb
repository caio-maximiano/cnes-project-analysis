# %% [markdown]
# | Etapa                      | Tecnologia recomendada                              | Justificativa                                           |
# | -------------------------- | --------------------------------------------------- | ------------------------------------------------------- |
# | Orquestração mensal        | `cron` no App Service ou Azure Functions            | Automação simples                                       |
# | Ambiente isolado           | Docker                                              | Facilita dependências (`duckdb`, `pandas`, `azure-sdk`) |
# | Extração + Upload Bronze   | Python puro (`requests`, `zipfile`, `DataLake SDK`) | Você já faz isso bem                                    |
# | Transformações Silver/Gold | `Pandas` ou `DuckDB`                                | Leves, simples, ideais para CSV                         |
# | Deploy                     | Azure App Service + GitHub Actions                  | CI/CD automatizado                                      |
#
#
# cnes-data-pipeline/
# │
# ├── Dockerfile
# ├── requirements.txt
# ├── app.py                  ← ponto de entrada principal
# ├── extract/
# │   └── extract_cnes.py     ← download e bronze upload
# ├── transform/
# │   ├── silver.py           ← limpeza e joins
# │   └── gold.py             ← agregações e finais
# ├── utils/
# │   └── azure_datalake.py   ← funções para leitura/escrita
# └── cron/
#     └── crontab.txt         ← para rodar mensalmente no container

# %%
from azure.storage.filedatalake import DataLakeServiceClient
import os

# Conexão com a conta
account_name = "cnesstorage"
account_key = "/ae47eZuE0NGPopxVHEkxOKsQwtEm3qQM0vBRPBRbB5nAW1zO6FPkEO9gwNQwkqExaVhOyHWgb68+AStIau+Uw=="#os.environ["AZURE_STORAGE_KEY"]
file_system_name = "bronze"

# Criar cliente
service_client = DataLakeServiceClient(
    account_url=f"https://{account_name}.dfs.core.windows.net",
    credential=account_key
)

file_system_client = service_client.get_file_system_client(file_system_name)

# Exibir apenas os arquivos de um mês

for path in file_system_client.get_paths(path="202406"):
    if path.name.endswith(".csv"):
        print(path.name)
# Out:
# 202406/rlAdmGerenciaCnes202406.csv
# 202406/rlAtividadeObrigatoria202406.csv
# 202406/rlCooperativa202406.csv
# 202406/rlEquipeAldeia202406.csv
# 202406/rlEquipeNasfEsf202406.csv
# 202406/rlEstabAtenPsico202406.csv
# 202406/rlEstabAtendPrestConv202406.csv
# 202406/rlEstabAvaliacao202406.csv
# 202406/rlEstabCentralReg202406.csv
# 202406/rlEstabColetaSelRejeito202406.csv
# 202406/rlEstabComissaoOutro202406.csv
# 202406/rlEstabComplementar202406.csv
# 202406/rlEstabEndCompl202406.csv
# 202406/rlEstabEqpEmbarcacao202406.csv
# 202406/rlEstabEqpUnidApoio202406.csv
# 202406/rlEstabEquipamento202406.csv
# 202406/rlEstabEquipeMun202406.csv
# 202406/rlEstabEquipeProf202406.csv
# 202406/rlEstabInstFisiAssist202406.csv
# 202406/rlEstabOrgParc202406.csv
# 202406/rlEstabPoloAldeia202406.csv
# 202406/rlEstabProfComissao202406.csv
# 202406/rlEstabProgFundo202406.csv
# 202406/rlEstabRegimeRes202406.csv
# 202406/rlEstabRepresentante202406.csv
# 202406/rlEstabSamu202406.csv
# 202406/rlEstabServClass202406.csv
# 202406/rlEstabServicoApoio202406.csv
# 202406/rlEstabSipac202406.csv
# 202406/rlEstabSubTipo202406.csv
# 202406/rlEstabTeleCnes202406.csv
# 202406/rlEstabUnidAcolhim202406.csv
# 202406/rlMunAtenPsico202406.csv
# 202406/rlMunRegimeRes202406.csv
# 202406/rlMunUnidAcolhim202406.csv
# 202406/rlNasfEsf202406.csv
# 202406/rlTipoEstabAtividade202406.csv
# 202406/tbAldeia202406.csv
# 202406/tbArea202406.csv
# 202406/tbAtendimentoPrestado202406.csv
# 202406/tbAtividade202406.csv
# 202406/tbAtividadeEnsino202406.csv
# 202406/tbAtividadeProfissional202406.csv
# 202406/tbAtributo202406.csv
# 202406/tbAvaliacao202406.csv
# 202406/tbBanco202406.csv
# 202406/tbCargaHorariaSus202406.csv
# 202406/tbClassificacaoAval202406.csv
# 202406/tbClassificacaoServico202406.csv
# 202406/tbColetaSeletivaRejeito202406.csv
# 202406/tbComissaoOutro202406.csv
# 202406/tbConselhoClasse202406.csv
# 202406/tbConvenio202406.csv
# 202406/tbDadosProfissionalSus202406.csv
# 202406/tbDialise202406.csv
# 202406/tbDsei202406.csv
# 202406/tbEquipamento202406.csv
# 202406/tbEquipe202406.csv
# 202406/tbEquipeAtendCompl202406.csv
# 202406/tbEquipeChDifer202406.csv
# 202406/tbEstabAtivSecundaria202406.csv
# 202406/tbEstabContrato202406.csv
# 202406/tbEstabHorarioAtend202406.csv
# 202406/tbEstabelecimento202406.csv
# 202406/tbEstado202406.csv
# 202406/tbEtnia202406.csv
# 202406/tbFluxoDadosClientela202406.csv
# 202406/tbGestao202406.csv
# 202406/tbGrupoAtividade202406.csv
# 202406/tbGrupoEquipe202406.csv
# 202406/tbHemoterapia202406.csv
# 202406/tbIncentivos202406.csv
# 202406/tbInstalFisicaParaAssist202406.csv
# 202406/tbInstituicaoAvaliadora202406.csv
# 202406/tbLeito202406.csv
# 202406/tbMantenedora202406.csv
# 202406/tbModVinculo202406.csv
# 202406/tbMotivoDesativEquipe202406.csv
# 202406/tbMotivoDesativacao202406.csv
# 202406/tbMunicipio202406.csv
# 202406/tbNaturezaJuridica202406.csv
# 202406/tbOrgaoEmissor202406.csv
# 202406/tbPoloBase202406.csv
# 202406/tbProfResidencia202406.csv
# 202406/tbQuimioRadio202406.csv
# 202406/tbResidenciaMed202406.csv
# 202406/tbSegmento202406.csv
# 202406/tbServicoApoio202406.csv
# 202406/tbServicoEspecializado202406.csv
# 202406/tbServicoReferenciado202406.csv
# 202406/tbSubGruposHabilitacao202406.csv
# 202406/tbSubTipo202406.csv
# 202406/tbSubTipoEquipe202406.csv
# 202406/tbSubTpModVinculo202406.csv
# 202406/tbSubtipoInstalacao202406.csv
# 202406/tbTipoAbrangencia202406.csv
# 202406/tbTipoCertidao202406.csv
# 202406/tbTipoCgDifer202406.csv
# 202406/tbTipoEqSubTipo202406.csv
# 202406/tbTipoEquipamento202406.csv
# 202406/tbTipoEquipe202406.csv
# 202406/tbTipoEscolaridade202406.csv
# 202406/tbTipoEstabelecimento202406.csv
# 202406/tbTipoInstalacaoFisica202406.csv
# 202406/tbTipoServicoReferenciado202406.csv
# 202406/tbTipoUnidade202406.csv
# 202406/tbTpModVinculo202406.csv
# 202406/tbTurnoAtendimento202406.csv

# %%
# ==== UPLOAD DE CSVs PARA O DATA LAKE ====
for root, _, files in os.walk(local_folder):
    for file_name in files:
        if file_name.lower().endswith(".csv"):
            local_path = os.path.join(root, file_name)
            blob_path = f"{target_dir}/{file_name}"

            print(f"Enviando {file_name} para abfss://{file_system_name}@{account_name}.dfs.core.windows.net/{blob_path}")

            file_client = file_system_client.get_file_client(blob_path)
            with open(local_path, "rb") as data:
                file_client.upload_data(
    data,
    overwrite=True,
    max_concurrency=4,            # número de uploads paralelos
    chunk_size=4 * 1024 * 1024    # 4 MB por chunk (ajustável)
)

print("Upload finalizado com DataLakeServiceClient.")

# %%
import pandas as pd
from io import BytesIO

# Nome do arquivo (coloque o que você viu acima)
remote_path = "202406/rlEstabAtenPsico202406.csv"

# Cliente do arquivo
file_client = file_system_client.get_file_client(remote_path)

# Download em memória
download = file_client.download_file()
downloaded_bytes = download.readall()

# Ler com pandas
df = pd.read_csv(BytesIO(downloaded_bytes), sep=';', encoding='latin1')  # ou ajuste para ',' e 'utf-8' se necessário
df.head()
# Out:
#       CO_UNIDADE  TP_ESTRUTURA ST_PARCERIA_ONG   NU_CNPJ_ONG  \
# 0  1702107566700             1               N           NaN
# 1  4304603731278             0               S  7.836454e+12
# 2  4304606691757             0               S  7.836454e+12
# 3  1100115054141             1               N           NaN
# 4  4311202243970             0               N           NaN
#
#    NU_VAGAS_ACOL_NOTUR CO_PROFISSIONAL_SUS  CO_CBO TP_SUS_NAO_SUS  \
# 0                    1    51652EB48CFA6A6C  131210              S
# 1                   10    8C22FD5A31AEBF04  142105              S
# 2                   10    CCBD98DBBCF6F484  131210              S
# 3                    0    14A00EB01AF8421A  131210              S
# 4                    0    55E8F61DDC47D816  251510              S
#
#    IND_VINCULACAO  CO_CNES_REFERENCIA ST_UNIDADE_REGIONAL  \
# 0           10301             2600536                   N
# 1           80400             3508528                   N
# 2           80400             3508528                   N
# 3           10405             2808609                   N
# 4           10101             2244306                   N
#
#   TO_CHAR(DT_ATUALIZACAO,'DD/MM/YYYY')   CO_USUARIO  \
# 0                           01/07/2024        SCNES
# 1                           23/02/2024  NOVOSTEMPOS
# 2                           01/07/2024      MARGANE
# 3                           11/06/2024       SEMSAU
# 4                           02/01/2024        SAUDE
#
#    TO_CHAR(DT_ATUALIZACAO_ORIGEM,'DD/MM/YYYY')
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN

# %% [markdown]
# # População

# %%
import re

year_cols = [c for c in df_pop.columns if re.fullmatch(r"\d{4}", str(c))]

df_pop_long = df_pop.melt(
    id_vars=["CO_MUNICIPIO", "NO_MUNICIPIO"],
    value_vars=year_cols,
    var_name="YYYY",
    value_name="POPULACAO"
)
print(df_pop_long.query("NO_MUNICIPIO == 'Sorocaba'"))



import pandas as pd
import numpy as np

# garante tipos
df = df_pop_long.copy()
df["YYYY"] = df["YYYY"].astype(int)
df["POPULACAO"] = pd.to_numeric(df["POPULACAO"], errors="coerce")
df["IMPUTED"] = False

# reindexa anos ausentes por município
def impute_geom(g):
    years = range(g["YYYY"].min(), g["YYYY"].max() + 1)
    g = g.set_index("YYYY").reindex(years)
    g["CO_MUNICIPIO"] = g["CO_MUNICIPIO"].ffill().bfill()
    g["NO_MUNICIPIO"] = g["NO_MUNICIPIO"].ffill().bfill()

    # interpolação geométrica: interpola log e depois exponencia
    mask_missing = g["POPULACAO"].isna()
    if mask_missing.any():
        y = np.log(g["POPULACAO"])
        y_interp = y.interpolate(method="linear", limit_direction="both")
        g.loc[mask_missing, "POPULACAO"] = np.exp(y_interp[mask_missing])
        g.loc[mask_missing, "IMPUTED"] = True
    else:
        g["IMPUTED"] = False

    g = g.reset_index().rename(columns={"index": "YYYY"})
    return g

df_populacao = (
    df.sort_values(["CO_MUNICIPIO", "YYYY"])
      .groupby(["CO_MUNICIPIO", "NO_MUNICIPIO"], group_keys=False)
      .apply(impute_geom)
      .astype({"YYYY": int})
)

df_populacao.to_csv("/Users/caio.maximiano/pessoal/cnes-project-analysis/local_storage/csv/populacao_imputada.csv", index=False)

# %%
import pandas as pd
from io import BytesIO

def build_nulls_summary_df(file_system_client, base_path, max_files=None):
    """
    Constrói um DataFrame com o nome do arquivo, colunas, tipos e % de nulos.

    Args:
        file_system_client: cliente do container (DataLake).
        base_path: diretório dentro do container (ex: "202406").
        max_files: máximo de arquivos para processar (opcional).
        
    Returns:
        DataFrame com colunas: ['arquivo', 'coluna', 'tipo', 'porcentagem_nulos']
    """
    summary_rows = []
    paths = file_system_client.get_paths(path=base_path)
    count = 0

    for path in paths:
        print(f"Checking {path}")
        if not path.name.endswith(".csv"):
            continue

        try:
            file_client = file_system_client.get_file_client(path.name)
            content = file_client.download_file().readall()
            df = pd.read_csv(BytesIO(content), sep=';', encoding='latin1')

            if df.empty:
                continue

            nulls_pct = df.isnull().mean() * 100

            for col in df.columns:
                summary_rows.append({
                    "arquivo": path.name,
                    "coluna": col,
                    "tipo": str(df[col].dtype),
                    "porcentagem_nulos": round(nulls_pct[col], 2)
                })

        except Exception as e:
            print(f"❌ Erro ao processar {path.name}: {e}")

        count += 1
        if max_files and count >= max_files:
            break

    return pd.DataFrame(summary_rows)

# %%
df_sanity = build_nulls_summary_df(file_system_client, "202406")
df_sanity.to_csv("./local_storage/exploring/sanity_cnes.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_sanity = build_nulls_summary_df(file_system_client, "202406")
#
# Cell In[5], line 26, in build_nulls_summary_df(file_system_client, base_path, max_files)
#      24 try:
#      25     file_client = file_system_client.get_file_client(path.name)
# ---> 26     content = file_client.download_file().readall()
#      27     df = pd.read_csv(BytesIO(content), sep=';', encoding='latin1')
#      29     if df.empty:
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/azure/core/tracing/decorator.py:119, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     117 # If tracing is disabled globally and user didn't explicitly enable it, don't trace.
#     118 if user_enabled is False or (not tracing_enabled and user_enabled is None):
# --> 119     return func(*args, **kwargs)
#     121 # Merge span is parameter is set, but only if no explicit parent are passed
#     122 if merge_span and not passed_in_parent:
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/azure/storage/filedatalake/_data_lake_file_client.py:705, in DataLakeFileClient.download_file(self, offset, length, **kwargs)
#     641 @distributed_trace
#     642 def download_file(
#     643     self, offset: Optional[int] = None,
#     644     length: Optional[int] = None,
#     645     **kwargs: Any
#     646 ) -> StorageStreamDownloader:
#     647     """Downloads a file to the StorageStreamDownloader. The readall() method must
#     648     be used to read all the content, or readinto() must be used to download the file into
#     649     a stream. Using chunks() returns an iterator which allows the user to iterate over the content in chunks.
#    (...)    703             :caption: Return the downloaded data.
#     704     """
# --> 705     downloader = self._blob_client.download_blob(offset=offset, length=length, **kwargs)
#     706     return StorageStreamDownloader(downloader)
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/azure/core/tracing/decorator.py:119, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     117 # If tracing is disabled globally and user didn't explicitly enable it, don't trace.
#     118 if user_enabled is False or (not tracing_enabled and user_enabled is None):
# --> 119     return func(*args, **kwargs)
#     121 # Merge span is parameter is set, but only if no explicit parent are passed
#     122 if merge_span and not passed_in_parent:
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/azure/storage/blob/_blob_client.py:753, in BlobClient.download_blob(self, offset, length, encoding, **kwargs)
#     735     raise ValueError("Customer provided encryption key must be used over HTTPS.")
#     736 options = _download_blob_options(
#     737     blob_name=self.blob_name,
#     738     container_name=self.container_name,
#    (...)    751     client=self._client,
#     752     **kwargs)
# --> 753 return StorageStreamDownloader(**options)
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/azure/storage/blob/_download.py:403, in StorageStreamDownloader.__init__(self, clients, config, start_range, end_range, validate_content, encryption_options, max_concurrency, name, container, encoding, download_cls, **kwargs)
#     393     initial_request_end = initial_request_start + first_get_size - 1
#     395 self._initial_range, self._initial_offset = process_range_and_offset(
#     396     initial_request_start,
#     397     initial_request_end,
#    (...)    400     self._encryption_data
#     401 )
# --> 403 self._response = self._initial_request()
#     404 self.properties = cast("BlobProperties", self._response.properties)
#     405 self.properties.name = self.name
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/azure/storage/blob/_download.py:510, in StorageStreamDownloader._initial_request(self)
#     508         self._current_content = b""
#     509     else:
# --> 510         self._current_content = process_content(
#     511             response,
#     512             self._initial_offset[0],
#     513             self._initial_offset[1],
#     514             self._encryption_options
#     515         )
#     516     retry_active = False
#     517 except (IncompleteReadError, HttpResponseError, DecodeError) as error:
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/azure/storage/blob/_download.py:66, in process_content(data, start_offset, end_offset, encryption)
#      63 if data is None:
#      64     raise ValueError("Response cannot be None.")
# ---> 66 content = b"".join(list(data))
#      68 if content and encryption.get("key") is not None or encryption.get("resolver") is not None:
#      69     try:
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/azure/core/pipeline/transport/_requests_basic.py:185, in StreamDownloadGenerator.__next__(self)
#     183 internal_response = self.response.internal_response
#     184 try:
# --> 185     chunk = next(self.iter_content_func)
#     186     if not chunk:
#     187         raise StopIteration()
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/urllib3/response.py:1091, in HTTPResponse.stream(self, amt, decode_content)
#    1089 else:
#    1090     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1091         data = self.read(amt=amt, decode_content=decode_content)
#    1093         if data:
#    1094             yield data
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/urllib3/response.py:980, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     977     if len(self._decoded_buffer) >= amt:
#     978         return self._decoded_buffer.get(amt)
# --> 980 data = self._raw_read(amt)
#     982 flush_decoder = amt is None or (amt != 0 and not data)
#     984 if not data and len(self._decoded_buffer) == 0:
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/urllib3/response.py:904, in HTTPResponse._raw_read(self, amt, read1)
#     901 fp_closed = getattr(self._fp, "closed", False)
#     903 with self._error_catcher():
# --> 904     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     905     if amt is not None and amt != 0 and not data:
#     906         # Platform-specific: Buggy versions of Python.
#     907         # Close the connection when no data is returned
#    (...)    912         # not properly close the connection in all cases. There is
#     913         # no harm in redundantly calling close.
#     914         self._fp.close()
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/urllib3/response.py:887, in HTTPResponse._fp_read(self, amt, read1)
#     884     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     885 else:
#     886     # StringIO doesn't like amt=None
# --> 887     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.10/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.10/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.12/3.12.10/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.10/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Métricas
# - Relação profissionais / população
# - Leitos hospitalares por habitante
# - Cobertura da Atenção Básica -> Proporção da população vinculada a equipes de saúde da família
#
# OBS: quebrar escopo para SP, olhar

# %%
# !pip install pandasql
# Out:
# Collecting pandasql
#   Using cached pandasql-0.7.3.tar.gz (26 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /Users/caio.maximiano/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages (from pandasql) (2.3.1)
# Requirement already satisfied: pandas in /Users/caio.maximiano/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages (from pandasql) (2.3.1)
# Collecting sqlalchemy (from pandasql)
#   Downloading sqlalchemy-2.0.43-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/caio.maximiano/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages (from pandas->pandasql) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/caio.maximiano/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages (from pandas->pandasql) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/caio.maximiano/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages (from pandas->pandasql) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/caio.maximiano/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->pandasql) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/caio.maximiano/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages (from sqlalchemy->pandasql) (4.14.1)
# Downloading sqlalchemy-2.0.43-cp312-cp312-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.0 MB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (pyproject.toml) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26867 sha256=9e80752a09d4b8b3e1cb72574cbfee8ea189abf638492d048db7ae3e74dfc3f1
#   Stored in directory: /Users/caio.maximiano/Library/Caches/pip/wheels/15/a1/e7/6f92f295b5272ae5c02365e6b8fa19cb93f16a537090a1cf27
# Successfully built pandasql
# Installing collected packages: sqlalchemy, pandasql
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandasql]y]
# Successfully installed pandasql-0.7.3 sqlalchemy-2.0.43
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import pandasql as ps

df = pd.read_csv("/Users/caio.maximiano/pessoal/cnes-project-analysis/exploration/output/cnes_202503_sanity_summary.csv", sep=',') 
query = "SELECT * from df"

resultado = ps.sqldf(query, locals())
resultado.head(10)
# Out:
#                            file_name sep encoding  load_time_sec  num_rows  \
# 0        rlAdmGerenciaCnes202503.csv   ,  latin-1         0.0121      4594
# 1   rlAtividadeObrigatoria202503.csv   ,    utf-8         0.0007        14
# 2            rlCooperativa202503.csv   ,    utf-8         0.0029      2308
# 3           rlEquipeAldeia202503.csv   ,    utf-8         0.0007       300
# 4          rlEquipeNasfEsf202503.csv   ;  latin-1         0.0909     86467
# 5         rlEstabAtenPsico202503.csv   ,  latin-1         0.0013      1373
# 6    rlEstabAtendPrestConv202503.csv   ,  latin-1         0.5452   1004536
# 7         rlEstabAvaliacao202503.csv   ,  latin-1         0.0014      1737
# 8        rlEstabCentralReg202503.csv   ,  latin-1         0.0049      3210
# 9  rlEstabColetaSelRejeito202503.csv   ,  latin-1         0.4640    851518
#
#    num_columns  memory_mb                                            columns
# 0            5      0.712  NU_CNPJ_ADM;"CO_UNIDADE";"TO_CHAR(DT_VIGENCIA_...
# 1            1      0.001  CO_TIPO_ESTABELECIMENTO;"CO_ATIVIDADE_OBRIGATO...
# 2            3      0.270  CO_UNIDADE;"CO_COOPERATIVA";"CO_CBO";"CO_USUAR...
# 3            3      0.039  CO_MUNICIPIO;"CO_AREA";"CO_SEQ_EQUIPE";"CO_ALD...
# 4           17     34.202  CO_MUNICIPIO, CO_AREA, SEQ_EQUIPE, CO_MUNICIPI...
# 5            3      0.229  CO_UNIDADE;"TP_ESTRUTURA";"ST_PARCERIA_ONG";"N...
# 6            3    108.831  CO_UNIDADE;"CO_ATENDIMENTO_PRESTADO";"CO_CONVE...
# 7            4      0.230  CO_UNIDADE;"CO_AVALIACAO";"CO_CLASSIFICACAO";"...
# 8            3      0.943  CO_UNIDADE;"CO_SEQ_CENTRAL";"NO_CENTRAL";"CO_S...
# 9            3     88.224  CO_UNIDADE;"CO_COLETA_REJEITO";"TO_CHAR(DT_ATU...

# %%
df = pd.read_csv("/Users/caio.maximiano/pessoal/cnes-project-analysis/exploration/output/cnes_202503_missingness_by_column.csv", sep=',') 
df.sort_values(by='column_name', ascending=False).head(15)
# Out:
#                             file_name         column_name  missing_pct sep  \
# 417       tbSubTpModVinculo202503.csv          TP_VINCULO         0.00   ;
# 264       tbEstabelecimento202503.csv          TP_UNIDADE         0.00   ;
# 182       tbCargaHorariaSus202503.csv     TP_TERCEIRO_SIH        31.60   ;
# 390         tbResidenciaMed202503.csv      TP_SUS_NAO_SUS         0.00   ;
# 180       tbCargaHorariaSus202503.csv      TP_SUS_NAO_SUS         0.00   ;
# 418       tbSubTpModVinculo202503.csv       TP_SUBVINCULO         0.00   ;
# 384         tbResidenciaMed202503.csv              TP_SRT         7.59   ;
# 188       tbCargaHorariaSus202503.csv        TP_RESIDENTE         0.00   ;
# 187       tbCargaHorariaSus202503.csv        TP_PRECEPTOR         0.00   ;
# 239       tbEstabelecimento202503.csv             TP_PFPJ         0.00   ;
# 410  tbSubGruposHabilitacao202503.csv           TP_ORIGEM        94.71   ;
# 261       tbEstabelecimento202503.csv  TP_ORGAO_EXPEDIDOR        31.42   ;
# 54          rlEstabEndCompl202503.csv             TP_LOGR         0.00   ;
# 263       tbEstabelecimento202503.csv         TP_LIC_SANI        59.01   ;
# 129            rlEstabSipac202503.csv      TP_HABILITACAO         0.00   ;
#
#     encoding
# 417  latin-1
# 264  latin-1
# 182  latin-1
# 390  latin-1
# 180  latin-1
# 418  latin-1
# 384  latin-1
# 188  latin-1
# 187  latin-1
# 239  latin-1
# 410  latin-1
# 261  latin-1
# 54   latin-1
# 263  latin-1
# 129  latin-1

# %% [markdown]
# # Especialidades
# MEDICO CARDIOLOGISTA -> 225120
# MEDICO CLINICO -> 225125
# MEDICO GERIATRA -> 225180
# MEDICO PEDIATRA -> 225124
# MEDICO DA ESTRATEGIA DE SAUDE DA FAMILIA -> 225142
# MEDICO GINECOLOGISTA E OBSTETRA -> 225250
# MEDICO NEUROLOGISTA -> 225112

# %% [markdown]
# # População

# %%
# !pip install thefuzz[speedup]
# Out:
# Collecting thefuzz[speedup]
#   Downloading thefuzz-0.22.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from thefuzz[speedup])
#   Downloading rapidfuzz-3.14.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Downloading thefuzz-0.22.1-py3-none-any.whl (8.2 kB)
# Downloading rapidfuzz-3.14.0-cp312-cp312-macosx_11_0_arm64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 4.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: rapidfuzz, thefuzz
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [thefuzz]
# Successfully installed rapidfuzz-3.14.0 thefuzz-0.22.1
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
from thefuzz import process

# Load data
df_pop = pd.read_csv("/Users/caio.maximiano/pessoal/cnes-project-analysis/local_storage/csv/populacao.csv")
df_estab = pd.read_csv("/Users/caio.maximiano/pessoal/cnes-project-analysis/local_storage/curated/estabelecimentos_202504.csv")

# Filter estabelecimentos
df_estab = df_estab.query(
    "CO_CBO in ('225120', '225125', '225180', '225124', '225142', '225250', '225112') & NO_MUNICIPIO in ('INDAIATUBA', 'SAO CARLOS')"
)

# Fuzzy match NO_MUNICIPIO
def fuzzy_match(municipio, choices, threshold=90):
    match, score = process.extractOne(municipio, choices)
    return match if score >= threshold else None

df_estab["NO_MUNICIPIO_MATCH"] = df_estab["NO_MUNICIPIO"].apply(
    lambda x: fuzzy_match(x, df_pop["NO_MUNICIPIO"].unique())
)

# Merge on matched municipio
df_merged = pd.merge(
    df_estab,
    df_pop,
    left_on="NO_MUNICIPIO_MATCH",
    right_on="NO_MUNICIPIO",
    suffixes=("_estab", "_pop")
)

df_merged.head()
# Out:
# /var/folders/q4/r947g97d1mdblr_m7b44wpfc0000gp/T/ipykernel_8446/2521052778.py:6: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_estab = pd.read_csv("/Users/caio.maximiano/pessoal/cnes-project-analysis/local_storage/curated/estabelecimentos_202504.csv")
#       CO_UNIDADE CO_PROFISSIONAL_SUS                     NO_PROFISSIONAL  \
# 0  3520500247480    A529AE6169C5B873      SERGIO AUGUSTO MARCELINO FILHO
# 1  3520500535176    61290B8EC9B61D93    FERNANDA JOSLIN OLIVEIRA REZENDE
# 2  3520500737852    98ED76DA3EE021AA           CRISTIAN RICARDO GONZALEZ
# 3  3520500737852    697156A3F88459E4                BRUNA GONZALEZ PORTO
# 4  3520500737852    BC7E25DDD69368BE  MARIANA DE OLIVEIRA SAMPAIO MATTOS
#
#    CO_CBO TP_SUS_NAO_SUS DS_ATIVIDADE_PROFISSIONAL  \
# 0  225120              N      MEDICO CARDIOLOGISTA
# 1  225120              N      MEDICO CARDIOLOGISTA
# 2  225125              N            MEDICO CLINICO
# 3  225125              N            MEDICO CLINICO
# 4  225125              N            MEDICO CLINICO
#
#                          NO_FANTASIA          NO_BAIRRO NO_MUNICIPIO_estab  \
# 0                           VITTACOR     JARDIM POMPEIA         INDAIATUBA
# 1  DIMEN MEDICINA NUCLEAR INDAIATUBA        CIDADE NOVA         INDAIATUBA
# 2             FOCO SAUDE OCUPACIONAL  JARDIM SANTA CRUZ         INDAIATUBA
# 3             FOCO SAUDE OCUPACIONAL  JARDIM SANTA CRUZ         INDAIATUBA
# 4             FOCO SAUDE OCUPACIONAL  JARDIM SANTA CRUZ         INDAIATUBA
#
#    CO_MUNICIPIO_estab CO_SIGLA_ESTADO    CO_CEP  \
# 0              352050              SP  13345040
# 1              352050              SP  13334070
# 2              352050              SP  13344000
# 3              352050              SP  13344000
# 4              352050              SP  13344000
#
#                    ds_localidade                            SK_REGISTRO  \
# 0  13345040,INDAIATUBA,SP,Brasil  3520500247480_A529AE6169C5B873_225120
# 1  13334070,INDAIATUBA,SP,Brasil  3520500535176_61290B8EC9B61D93_225120
# 2  13344000,INDAIATUBA,SP,Brasil  3520500737852_98ED76DA3EE021AA_225125
# 3  13344000,INDAIATUBA,SP,Brasil  3520500737852_697156A3F88459E4_225125
# 4  13344000,INDAIATUBA,SP,Brasil  3520500737852_BC7E25DDD69368BE_225125
#
#   DATA_INGESTAO NO_MUNICIPIO_MATCH  CO_MUNICIPIO_pop NO_MUNICIPIO_pop  \
# 0    2025-08-20         Indaiatuba             20509       Indaiatuba
# 1    2025-08-20         Indaiatuba             20509       Indaiatuba
# 2    2025-08-20         Indaiatuba             20509       Indaiatuba
# 3    2025-08-20         Indaiatuba             20509       Indaiatuba
# 4    2025-08-20         Indaiatuba             20509       Indaiatuba
#
#       2011     2012     2013     2014     2015     2016     2017     2018  \
# 0  205.808  209.859  222.042  226.602  231.033  235.367  239.602  246.908
# 1  205.808  209.859  222.042  226.602  231.033  235.367  239.602  246.908
# 2  205.808  209.859  222.042  226.602  231.033  235.367  239.602  246.908
# 3  205.808  209.859  222.042  226.602  231.033  235.367  239.602  246.908
# 4  205.808  209.859  222.042  226.602  231.033  235.367  239.602  246.908
#
#       2019     2020    2021     2024     2025
# 0  251.627  256.223  260.69  267.796  269.657
# 1  251.627  256.223  260.69  267.796  269.657
# 2  251.627  256.223  260.69  267.796  269.657
# 3  251.627  256.223  260.69  267.796  269.657
# 4  251.627  256.223  260.69  267.796  269.657

# %%
import pandas as pd
import pandasql as ps

df = pd.read_csv("/Users/caio.maximiano/pessoal/cnes-project-analysis/local_storage/curated/estabelecimentos_202504.csv")
df = df.query("CO_CBO in ('225120', '225125', '225180', '225124', '225142', '225250', '225112') & NO_MUNICIPIO in ('INDAIATUBA', 'SAO CARLOS')")

query = "SELECT NO_MUNICIPIO,DS_ATIVIDADE_PROFISSIONAL, count( distinct CO_PROFISSIONAL_SUS) from df group by NO_MUNICIPIO, DS_ATIVIDADE_PROFISSIONAL"

resultado = ps.sqldf(query, locals())
resultado.head(10)
# Out:
# /var/folders/q4/r947g97d1mdblr_m7b44wpfc0000gp/T/ipykernel_8446/1333811580.py:4: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/caio.maximiano/pessoal/cnes-project-analysis/local_storage/curated/estabelecimentos_202504.csv")
#   NO_MUNICIPIO                 DS_ATIVIDADE_PROFISSIONAL  \
# 0   INDAIATUBA                      MEDICO CARDIOLOGISTA
# 1   INDAIATUBA                            MEDICO CLINICO
# 2   INDAIATUBA  MEDICO DA ESTRATEGIA DE SAUDE DA FAMILIA
# 3   INDAIATUBA                           MEDICO GERIATRA
# 4   INDAIATUBA           MEDICO GINECOLOGISTA E OBSTETRA
# 5   INDAIATUBA                       MEDICO NEUROLOGISTA
# 6   INDAIATUBA                           MEDICO PEDIATRA
# 7   SAO CARLOS                      MEDICO CARDIOLOGISTA
# 8   SAO CARLOS                            MEDICO CLINICO
# 9   SAO CARLOS  MEDICO DA ESTRATEGIA DE SAUDE DA FAMILIA
#
#    count( distinct CO_PROFISSIONAL_SUS)
# 0                                    47
# 1                                   879
# 2                                    50
# 3                                     3
# 4                                   181
# 5                                    45
# 6                                   209
# 7                                    62
# 8                                   450
# 9                                    20

# %%
# !pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-21.0.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Downloading pyarrow-21.0.0-cp312-cp312-macosx_12_0_arm64.whl (31.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.2/31.2 MB 5.9 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pyarrow
# Successfully installed pyarrow-21.0.0
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
from io import BytesIO
from azure.storage.filedatalake import DataLakeServiceClient

# Connection info
account_name = "cnesstorage"
account_key = "/ae47eZuE0NGPopxVHEkxOKsQwtEm3qQM0vBRPBRbB5nAW1zO6FPkEO9gwNQwkqExaVhOyHWgb68+AStIau+Uw=="

datalake_client = DataLakeServiceClient(
    account_url=f"https://{account_name}.dfs.core.windows.net",
    credential=account_key,
)
silver_fs_client = datalake_client.get_file_system_client("silver")
gold_fs_client = datalake_client.get_file_system_client("gold")

def read_all_curated_periods(fs_client, prefix, sep=",", encoding="utf-8"):
    """
    Reads all CSVs with the given prefix from the silver container, concatenates, and adds yyyymm column.
    """
    all_dfs = []
    for path in fs_client.get_paths():
        if path.name.endswith('.csv') and f"/{prefix}_" in path.name:
            # Extract yyyymm from filename, e.g., estabelecimentos_202201.csv
            yyyymm = path.name.split("_")[-1].replace(".csv", "")
            try:
                file_client = fs_client.get_file_client(path.name)
                content = file_client.download_file().readall()
                df = pd.read_csv(BytesIO(content), sep=sep, encoding=encoding)
                df["yyyymm"] = yyyymm
                all_dfs.append(df)
            except Exception as e:
                print(f"Erro ao ler {path.name}: {e}")
    if all_dfs:
        return pd.concat(all_dfs, ignore_index=True)
    else:
        return pd.DataFrame()

def save_parquet_to_gold(fs_client, df, filename):
    """
    Save DataFrame as Parquet in the 'gold' container of the Data Lake.
    """
    import io
    buffer = io.BytesIO()
    df.to_parquet(buffer, index=False, engine="pyarrow")
    buffer.seek(0)
    file_client = fs_client.get_file_client(filename)
    file_client.upload_data(buffer.read(), overwrite=True)
    print(f"Arquivo Parquet salvo em gold/{filename}")

# Example for estabelecimentos:
df_estab_all = read_all_curated_periods(silver_fs_client, "estabelecimentos")
save_parquet_to_gold(gold_fs_client, df_estab_all, "estabelecimentos_all_periods.parquet")

# Example for servicos:
# df_serv_all = read_all_curated_periods(silver_fs_client, "servicos")
# save_parquet_to_gold(gold_fs_client, df_serv_all, "servicos_all_periods.parquet")
# Out:
# /var/folders/q4/r947g97d1mdblr_m7b44wpfc0000gp/T/ipykernel_29753/3292636821.py:28: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(BytesIO(content), sep=sep, encoding=encoding)
# /var/folders/q4/r947g97d1mdblr_m7b44wpfc0000gp/T/ipykernel_29753/3292636821.py:28: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(BytesIO(content), sep=sep, encoding=encoding)
# /var/folders/q4/r947g97d1mdblr_m7b44wpfc0000gp/T/ipykernel_29753/3292636821.py:28: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(BytesIO(content), sep=sep, encoding=encoding)
# /var/folders/q4/r947g97d1mdblr_m7b44wpfc0000gp/T/ipykernel_29753/3292636821.py:28: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(BytesIO(content), sep=sep, encoding=encoding)
# /var/folders/q4/r947g97d1mdblr_m7b44wpfc0000gp/T/ipykernel_29753/3292636821.py:28: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(BytesIO(content), sep=sep, encoding=encoding)
# /var/folders/q4/r947g97d1mdblr_m7b44wpfc0000gp/T/ipykernel_29753/3292636821.py:28: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(BytesIO(content), sep=sep, encoding=encoding)
# /var/folders/q4/r947g97d1mdblr_m7b44wpfc0000gp/T/ipykernel_29753/3292636821.py:28: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(BytesIO(content), sep=sep, encoding=encoding)
# /var/folders/q4/r947g97d1mdblr_m7b44wpfc0000gp/T/ipykernel_29753/3292636821.py:28: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(BytesIO(content), sep=sep, encoding=encoding)
# /var/folders/q4/r947g97d1mdblr_m7b44wpfc0000gp/T/ipykernel_29753/3292636821.py:28: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(BytesIO(content), sep=sep, encoding=encoding)
# /var/folders/q4/r947g97d1mdblr_m7b44wpfc0000gp/T/ipykernel_29753/3292636821.py:28: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(BytesIO(content), sep=sep, encoding=encoding)
# /var/folders/q4/r947g97d1mdblr_m7b44wpfc0000gp/T/ipykernel_29753/3292636821.py:28: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(BytesIO(content), sep=sep, encoding=encoding)
# /var/folders/q4/r947g97d1mdblr_m7b44wpfc0000gp/T/ipykernel_29753/3292636821.py:28: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(BytesIO(content), sep=sep, encoding=encoding)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 51
#      48     print(f"Arquivo Parquet salvo em gold/{filename}")
#      50 # Example for estabelecimentos:
# ---> 51 df_estab_all = read_all_curated_periods(silver_fs_client, "estabelecimentos")
#      52 save_parquet_to_gold(gold_fs_client, df_estab_all, "estabelecimentos_all_periods.parquet")
#      54 # Example for servicos:
#      55 # df_serv_all = read_all_curated_periods(silver_fs_client, "servicos")
#      56 # save_parquet_to_gold(gold_fs_client, df_serv_all, "servicos_all_periods.parquet")
#
# Cell In[5], line 27, in read_all_curated_periods(fs_client, prefix, sep, encoding)
#      25 try:
#      26     file_client = fs_client.get_file_client(path.name)
# ---> 27     content = file_client.download_file().readall()
#      28     df = pd.read_csv(BytesIO(content), sep=sep, encoding=encoding)
#      29     df["yyyymm"] = yyyymm
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/azure/storage/filedatalake/_download.py:80, in StorageStreamDownloader.readall(self)
#      72 def readall(self) -> bytes:
#      73     """Download the contents of this file.
#      74
#      75     This operation is blocking until all data is downloaded.
#    (...)     78     :rtype: bytes
#      79     """
# ---> 80     return cast(bytes, self._downloader.readall())
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/azure/storage/blob/_download.py:763, in StorageStreamDownloader.readall(self)
#     755 def readall(self) -> T:
#     756     """
#     757     Read the entire contents of this blob.
#     758     This operation is blocking until all data is downloaded.
#    (...)    761     :rtype: T
#     762     """
# --> 763     return self.read()
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/azure/storage/blob/_download.py:717, in StorageStreamDownloader.read(self, size, chars)
#     715     else:
#     716         for next_chunk in chunks_iter:
# --> 717             downloader.process_chunk(next_chunk)
#     719     self._complete_read()
#     721 else:
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/azure/storage/blob/_download.py:147, in _ChunkDownloader.process_chunk(self, chunk_start)
#     145 def process_chunk(self, chunk_start: int) -> None:
#     146     chunk_start, chunk_end = self._calculate_range(chunk_start)
# --> 147     chunk_data, _ = self._download_chunk(chunk_start, chunk_end - 1)
#     148     length = chunk_end - chunk_start
#     149     if length > 0:
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/azure/storage/blob/_download.py:236, in _ChunkDownloader._download_chunk(self, chunk_start, chunk_end)
#     233     process_storage_error(error)
#     235 try:
# --> 236     chunk_data = process_content(response, offset[0], offset[1], self.encryption_options)
#     237     retry_active = False
#     238 except (IncompleteReadError, HttpResponseError, DecodeError) as error:
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/azure/storage/blob/_download.py:66, in process_content(data, start_offset, end_offset, encryption)
#      63 if data is None:
#      64     raise ValueError("Response cannot be None.")
# ---> 66 content = b"".join(list(data))
#      68 if content and encryption.get("key") is not None or encryption.get("resolver") is not None:
#      69     try:
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/azure/core/pipeline/transport/_requests_basic.py:185, in StreamDownloadGenerator.__next__(self)
#     183 internal_response = self.response.internal_response
#     184 try:
# --> 185     chunk = next(self.iter_content_func)
#     186     if not chunk:
#     187         raise StopIteration()
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/urllib3/response.py:1091, in HTTPResponse.stream(self, amt, decode_content)
#    1089 else:
#    1090     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1091         data = self.read(amt=amt, decode_content=decode_content)
#    1093         if data:
#    1094             yield data
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/urllib3/response.py:980, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     977     if len(self._decoded_buffer) >= amt:
#     978         return self._decoded_buffer.get(amt)
# --> 980 data = self._raw_read(amt)
#     982 flush_decoder = amt is None or (amt != 0 and not data)
#     984 if not data and len(self._decoded_buffer) == 0:
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/urllib3/response.py:904, in HTTPResponse._raw_read(self, amt, read1)
#     901 fp_closed = getattr(self._fp, "closed", False)
#     903 with self._error_catcher():
# --> 904     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     905     if amt is not None and amt != 0 and not data:
#     906         # Platform-specific: Buggy versions of Python.
#     907         # Close the connection when no data is returned
#    (...)    912         # not properly close the connection in all cases. There is
#     913         # no harm in redundantly calling close.
#     914         self._fp.close()
#
# File ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/urllib3/response.py:887, in HTTPResponse._fp_read(self, amt, read1)
#     884     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     885 else:
#     886     # StringIO doesn't like amt=None
# --> 887     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.10/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.10/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.12/3.12.10/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.10/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# !pip install fastparquet
# Out:
# Collecting fastparquet
#   Downloading fastparquet-2024.11.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Requirement already satisfied: pandas>=1.5.0 in /Users/caio.maximiano/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages (from fastparquet) (2.3.1)
# Requirement already satisfied: numpy in /Users/caio.maximiano/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages (from fastparquet) (2.3.1)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.11.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Collecting fsspec (from fastparquet)
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging in /Users/caio.maximiano/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages (from fastparquet) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/caio.maximiano/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/caio.maximiano/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/caio.maximiano/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/caio.maximiano/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Downloading fastparquet-2024.11.0-cp312-cp312-macosx_11_0_arm64.whl (685 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 685.4/685.4 kB 9.2 MB/s eta 0:00:00
# Downloading cramjam-2.11.0-cp312-cp312-macosx_11_0_arm64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.3 MB/s eta 0:00:00a 0:00:01
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Installing collected packages: fsspec, cramjam, fastparquet
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [fastparquet]
# Successfully installed cramjam-2.11.0 fastparquet-2024.11.0 fsspec-2025.9.0
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
from io import BytesIO
from azure.storage.filedatalake import DataLakeServiceClient

# Connection info
account_name = "cnesstorage"
account_key = "/ae47eZuE0NGPopxVHEkxOKsQwtEm3qQM0vBRPBRbB5nAW1zO6FPkEO9gwNQwkqExaVhOyHWgb68+AStIau+Uw=="

datalake_client = DataLakeServiceClient(
    account_url=f"https://{account_name}.dfs.core.windows.net",
    credential=account_key,
)
silver_fs_client = datalake_client.get_file_system_client("silver")
gold_fs_client = datalake_client.get_file_system_client("gold")

def read_all_curated_periods(fs_client, prefix, sep=",", encoding="utf-8", periods=None):
    """
    Reads all CSVs with the given prefix from the silver container, concatenates, and adds yyyymm column.
    If periods is provided, only loads files for those periods (list of strings, e.g. ['202201','202202']).
    """
    all_dfs = []
    for path in fs_client.get_paths():
        if path.name.endswith('.csv') and f"/{prefix}_" in path.name:
            yyyymm = path.name.split("_")[-1].replace(".csv", "")
            if periods is not None and yyyymm not in periods:
                continue
            try:
                print(f"Lendo {path.name}")
                file_client = fs_client.get_file_client(path.name)
                content = file_client.download_file().readall()
                df = pd.read_csv(BytesIO(content), sep=sep, encoding=encoding,dtype=str)
                df["yyyymm"] = yyyymm
                all_dfs.append(df)
                print(f"DataFrame para {yyyymm} adicionado.")
            except Exception as e:
                print(f"Erro ao ler {path.name}: {e}")
    if all_dfs:
        return pd.concat(all_dfs, ignore_index=True)
    else:
        return pd.DataFrame()

def save_parquet_to_gold(fs_client, df, filename):
    """
    Save DataFrame as Parquet in the 'gold' container of the Data Lake.
    """
    print(f"Salvando {filename} no formato Parquet.")
    import io
    buffer = io.BytesIO()
    df.to_parquet(buffer, index=False, engine="fastparquet")
    buffer.seek(0)
    file_client = fs_client.get_file_client(filename)
    file_client.upload_data(buffer.read(), overwrite=True)
    print(f"Arquivo Parquet salvo em gold/{filename}")

# range from Jan 2022 to Jul 2025 inclusive
periods = pd.period_range("202201", "202507", freq="M").strftime("%Y%m").tolist()

df_estab_range = read_all_curated_periods(
    silver_fs_client,
    "estabelecimentos",
    periods=periods
)

save_parquet_to_gold(
    gold_fs_client,
    df_estab_range,
    "estabelecimentos_all.parquet"
)

# Example for all periods (default):
df_estab_all = read_all_curated_periods(
    silver_fs_client,
    "estabelecimentos",
    periods=periods
)

save_parquet_to_gold(
    gold_fs_client,
    df_estab_all,
    "estabelecimentos_all.parquet"
)
# Out:
# Lendo 202201/estabelecimentos_202201.csv
# DataFrame para 202201 adicionado.
# Lendo 202202/estabelecimentos_202202.csv
# DataFrame para 202202 adicionado.
# Lendo 202203/estabelecimentos_202203.csv
# DataFrame para 202203 adicionado.
# Lendo 202204/estabelecimentos_202204.csv
# DataFrame para 202204 adicionado.
# Lendo 202205/estabelecimentos_202205.csv
# DataFrame para 202205 adicionado.
# Lendo 202206/estabelecimentos_202206.csv
# DataFrame para 202206 adicionado.
# Lendo 202207/estabelecimentos_202207.csv
# DataFrame para 202207 adicionado.
# Lendo 202208/estabelecimentos_202208.csv
# DataFrame para 202208 adicionado.
# Lendo 202209/estabelecimentos_202209.csv
# DataFrame para 202209 adicionado.
# Lendo 202210/estabelecimentos_202210.csv
# DataFrame para 202210 adicionado.
# Lendo 202212/estabelecimentos_202212.csv
# DataFrame para 202212 adicionado.
# Lendo 202301/estabelecimentos_202301.csv
# DataFrame para 202301 adicionado.
# Lendo 202302/estabelecimentos_202302.csv
# DataFrame para 202302 adicionado.
# Lendo 202303/estabelecimentos_202303.csv
# DataFrame para 202303 adicionado.
# Lendo 202304/estabelecimentos_202304.csv
# DataFrame para 202304 adicionado.
# Lendo 202305/estabelecimentos_202305.csv
# DataFrame para 202305 adicionado.
# Lendo 202306/estabelecimentos_202306.csv
# DataFrame para 202306 adicionado.
# Lendo 202307/estabelecimentos_202307.csv
# DataFrame para 202307 adicionado.
# Lendo 202308/estabelecimentos_202308.csv
# DataFrame para 202308 adicionado.
# Lendo 202310/estabelecimentos_202310.csv
# DataFrame para 202310 adicionado.
# Lendo 202312/estabelecimentos_202312.csv
# DataFrame para 202312 adicionado.
# Lendo 202401/estabelecimentos_202401.csv
# Erro ao ler 202401/estabelecimentos_202401.csv: No columns to parse from file
# Lendo 202402/estabelecimentos_202402.csv
# DataFrame para 202402 adicionado.
# Lendo 202403/estabelecimentos_202403.csv
# Unable to stream download.
# Erro ao ler 202403/estabelecimentos_202403.csv: HTTPSConnectionPool(host='cnesstorage.blob.core.windows.net', port=443): Read timed out.
# Lendo 202404/estabelecimentos_202404.csv
# Unable to stream download.
# Erro ao ler 202404/estabelecimentos_202404.csv: HTTPSConnectionPool(host='cnesstorage.blob.core.windows.net', port=443): Read timed out.
# Lendo 202405/estabelecimentos_202405.csv
# Unable to stream download.
# Erro ao ler 202405/estabelecimentos_202405.csv: [SSL] record layer failure (_ssl.c:2580)
# Lendo 202406/estabelecimentos_202406.csv
# Erro ao ler 202406/estabelecimentos_202406.csv: No columns to parse from file
# Lendo 202407/estabelecimentos_202407.csv
# Unable to stream download.
# DataFrame para 202407 adicionado.
# Lendo 202408/estabelecimentos_202408.csv
# Unable to stream download.
# Erro ao ler 202408/estabelecimentos_202408.csv: [SSL] record layer failure (_ssl.c:2580)
# Lendo 202409/estabelecimentos_202409.csv
# Unable to stream download.
# Erro ao ler 202409/estabelecimentos_202409.csv: HTTPSConnectionPool(host='cnesstorage.blob.core.windows.net', port=443): Read timed out.
# Lendo 202410/estabelecimentos_202410.csv
# Unable to stream download.
# Unable to stream download.
# Unable to stream download.
# Erro ao ler 202410/estabelecimentos_202410.csv: HTTPSConnectionPool(host='cnesstorage.blob.core.windows.net', port=443): Read timed out.
# Lendo 202411/estabelecimentos_202411.csv
# Unable to stream download.
# Erro ao ler 202411/estabelecimentos_202411.csv: HTTPSConnectionPool(host='cnesstorage.blob.core.windows.net', port=443): Read timed out.
# Lendo 202501/estabelecimentos_202501.csv
# Unable to stream download.
# Unable to stream download.
# Unable to stream download.
# Erro ao ler 202501/estabelecimentos_202501.csv: HTTPSConnectionPool(host='cnesstorage.blob.core.windows.net', port=443): Read timed out.
# Lendo 202502/estabelecimentos_202502.csv
# Unable to stream download.
# Erro ao ler 202502/estabelecimentos_202502.csv: HTTPSConnectionPool(host='cnesstorage.blob.core.windows.net', port=443): Read timed out.
# Lendo 202504/estabelecimentos_202504.csv
# Unable to stream download.
# Erro ao ler 202504/estabelecimentos_202504.csv: HTTPSConnectionPool(host='cnesstorage.blob.core.windows.net', port=443): Read timed out.
# Lendo 202506/estabelecimentos_202506.csv
# Unable to stream download.
# Unable to stream download.
# Erro ao ler 202506/estabelecimentos_202506.csv: HTTPSConnectionPool(host='cnesstorage.blob.core.windows.net', port=443): Read timed out.
# Lendo 202507/estabelecimentos_202507.csv
# Unable to stream download.
# Erro ao ler 202507/estabelecimentos_202507.csv: HTTPSConnectionPool(host='cnesstorage.blob.core.windows.net', port=443): Read timed out.
# Salvando estabelecimentos_all.parquet no formato Parquet.
# Arquivo Parquet salvo em gold/estabelecimentos_all.parquet
# Lendo 202201/estabelecimentos_202201.csv
# DataFrame para 202201 adicionado.
# Lendo 202202/estabelecimentos_202202.csv
# DataFrame para 202202 adicionado.
# Lendo 202203/estabelecimentos_202203.csv
# DataFrame para 202203 adicionado.
# Lendo 202204/estabelecimentos_202204.csv
# DataFrame para 202204 adicionado.
# Lendo 202205/estabelecimentos_202205.csv
# DataFrame para 202205 adicionado.
# Lendo 202206/estabelecimentos_202206.csv
# DataFrame para 202206 adicionado.
# Lendo 202207/estabelecimentos_202207.csv
# DataFrame para 202207 adicionado.
# Lendo 202208/estabelecimentos_202208.csv
# DataFrame para 202208 adicionado.
# Lendo 202209/estabelecimentos_202209.csv
# DataFrame para 202209 adicionado.
# Lendo 202210/estabelecimentos_202210.csv
# DataFrame para 202210 adicionado.
# Lendo 202212/estabelecimentos_202212.csv
# DataFrame para 202212 adicionado.
# Lendo 202301/estabelecimentos_202301.csv
# DataFrame para 202301 adicionado.
# Lendo 202302/estabelecimentos_202302.csv
# DataFrame para 202302 adicionado.
# Lendo 202303/estabelecimentos_202303.csv
# DataFrame para 202303 adicionado.
# Lendo 202304/estabelecimentos_202304.csv
# DataFrame para 202304 adicionado.
# Lendo 202305/estabelecimentos_202305.csv
# DataFrame para 202305 adicionado.
# Lendo 202306/estabelecimentos_202306.csv
# DataFrame para 202306 adicionado.
# Lendo 202307/estabelecimentos_202307.csv
# DataFrame para 202307 adicionado.
# Lendo 202308/estabelecimentos_202308.csv
# DataFrame para 202308 adicionado.
# Lendo 202310/estabelecimentos_202310.csv
# DataFrame para 202310 adicionado.
# Lendo 202312/estabelecimentos_202312.csv
# DataFrame para 202312 adicionado.
# Lendo 202401/estabelecimentos_202401.csv
# Erro ao ler 202401/estabelecimentos_202401.csv: No columns to parse from file
# Lendo 202402/estabelecimentos_202402.csv
# DataFrame para 202402 adicionado.
# Lendo 202403/estabelecimentos_202403.csv
# DataFrame para 202403 adicionado.
# Lendo 202404/estabelecimentos_202404.csv
# DataFrame para 202404 adicionado.
# Lendo 202405/estabelecimentos_202405.csv
# DataFrame para 202405 adicionado.
# Lendo 202406/estabelecimentos_202406.csv
# Erro ao ler 202406/estabelecimentos_202406.csv: No columns to parse from file
# Lendo 202407/estabelecimentos_202407.csv
# DataFrame para 202407 adicionado.
# Lendo 202408/estabelecimentos_202408.csv
# DataFrame para 202408 adicionado.
# Lendo 202409/estabelecimentos_202409.csv
# DataFrame para 202409 adicionado.
# Lendo 202410/estabelecimentos_202410.csv
# DataFrame para 202410 adicionado.
# Lendo 202411/estabelecimentos_202411.csv
# DataFrame para 202411 adicionado.
# Lendo 202501/estabelecimentos_202501.csv
# DataFrame para 202501 adicionado.
# Lendo 202502/estabelecimentos_202502.csv
# DataFrame para 202502 adicionado.
# Lendo 202504/estabelecimentos_202504.csv
# DataFrame para 202504 adicionado.
# Lendo 202506/estabelecimentos_202506.csv
# DataFrame para 202506 adicionado.
# Lendo 202507/estabelecimentos_202507.csv
# DataFrame para 202507 adicionado.
# Salvando estabelecimentos_all.parquet no formato Parquet.
# Arquivo Parquet salvo em gold/estabelecimentos_all.parquet

# %%
df = pd.read_csv("/Users/caio.maximiano/pessoal/cnes-project-analysis/local_storage/curated/servicos_202504.csv", sep=',') 
df.columns
# Out:
# /var/folders/q4/r947g97d1mdblr_m7b44wpfc0000gp/T/ipykernel_8446/1210615949.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/caio.maximiano/pessoal/cnes-project-analysis/local_storage/curated/servicos_202504.csv", sep=',')
# Index(['CO_UNIDADE', 'NO_MUNICIPIO', 'CO_MUNICIPIO', 'CO_SERVICO',
#        'CO_CLASSIFICACAO', 'DS_CLASSIFICACAO_SERVICO', 'SK_REGISTRO',
#        'DATA_INGESTAO'],
#       dtype='object')
