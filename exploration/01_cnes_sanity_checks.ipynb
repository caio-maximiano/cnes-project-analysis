# %% [markdown]
# # CNES 2025-03 — Sanity Checks
#
# This notebook performs sanity checks on the CNES CSV extract for 2025-03 located in `local_storage/csv/cnes_extract_202503`.
#
# It will:
# - Detect delimiter and encoding per file
# - Load the dataframes safely
# - Report row/column counts, memory usage, dtypes
# - Compute basic missingness stats
# - Save a summary report under `exploration/output/`

# %%
from pathlib import Path
import time
import pandas as pd

# Paths
PROJECT_ROOT = Path("/Users/caio.maximiano/pessoal/cnes-project-analysis")
if not PROJECT_ROOT.exists():
    PROJECT_ROOT = Path.cwd().resolve()

DATA_DIR = PROJECT_ROOT / "local_storage/csv/cnes_extract_202503"
OUTPUT_DIR = PROJECT_ROOT / "exploration" / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

DATA_DIR
# Out:
# PosixPath('/Users/caio.maximiano/pessoal/cnes-project-analysis/local_storage/csv/cnes_extract_202503')

# %%
# List CSV files
csv_files = sorted([p for p in DATA_DIR.glob("*.csv")])
len(csv_files), csv_files[:5]
# Out:
# (108,
#  [PosixPath('/Users/caio.maximiano/pessoal/cnes-project-analysis/local_storage/csv/cnes_extract_202503/rlAdmGerenciaCnes202503.csv'),
#   PosixPath('/Users/caio.maximiano/pessoal/cnes-project-analysis/local_storage/csv/cnes_extract_202503/rlAtividadeObrigatoria202503.csv'),
#   PosixPath('/Users/caio.maximiano/pessoal/cnes-project-analysis/local_storage/csv/cnes_extract_202503/rlCooperativa202503.csv'),
#   PosixPath('/Users/caio.maximiano/pessoal/cnes-project-analysis/local_storage/csv/cnes_extract_202503/rlEquipeAldeia202503.csv'),
#   PosixPath('/Users/caio.maximiano/pessoal/cnes-project-analysis/local_storage/csv/cnes_extract_202503/rlEquipeNasfEsf202503.csv')])

# %%
# Robust CSV loader that tries common separators and encodings
from typing import Optional, Tuple, Dict, Any

COMMON_SEPARATORS = [",", ";", "|", "\t"]
COMMON_ENCODINGS = ["utf-8", "latin-1", "cp1252"]


def try_read_csv(path: Path, nrows: Optional[int] = None) -> Tuple[pd.DataFrame, Dict[str, Any]]:
    last_error = None
    for enc in COMMON_ENCODINGS:
        for sep in COMMON_SEPARATORS:
            try:
                start = time.time()
                df = pd.read_csv(path, sep=sep, encoding=enc, nrows=nrows, low_memory=False)
                elapsed = time.time() - start
                return df, {"encoding": enc, "sep": sep, "load_time_sec": round(elapsed, 4)}
            except Exception as e:
                last_error = e
                continue
    raise RuntimeError(f"Failed to read {path.name}. Last error: {last_error}")


def dataframe_memory_mb(df: pd.DataFrame) -> float:
    return round(df.memory_usage(deep=True).sum() / (1024 ** 2), 3)

# %%
# Iterate files, compute sanity metrics, and save a summary
from collections import OrderedDict

summary_rows = []

for csv_path in csv_files:
    print(f"Loading {csv_path.name} ...")
    df, meta = try_read_csv(csv_path)

    num_rows, num_cols = df.shape
    mem_mb = dataframe_memory_mb(df)
    dtypes = df.dtypes.astype(str).to_dict()
    missing_pct = (df.isna().mean() * 100).round(2).sort_values(ascending=False)

    row = OrderedDict(
        file_name=csv_path.name,
        sep=meta["sep"],
        encoding=meta["encoding"],
        load_time_sec=meta["load_time_sec"],
        num_rows=num_rows,
        num_columns=num_cols,
        memory_mb=mem_mb,
        columns=", ".join(df.columns.tolist()),
    )
    summary_rows.append(row)

summary_df = pd.DataFrame(summary_rows)
summary_path = OUTPUT_DIR / "cnes_202503_sanity_summary.csv"
summary_df.to_csv(summary_path, index=False)
summary_df.head(10)
# Out:
# Loading rlAdmGerenciaCnes202503.csv ...
# Loading rlAtividadeObrigatoria202503.csv ...
# Loading rlCooperativa202503.csv ...
# Loading rlEquipeAldeia202503.csv ...
# Loading rlEquipeNasfEsf202503.csv ...
# Loading rlEstabAtenPsico202503.csv ...
# Loading rlEstabAtendPrestConv202503.csv ...
# Loading rlEstabAvaliacao202503.csv ...
# Loading rlEstabCentralReg202503.csv ...
# Loading rlEstabColetaSelRejeito202503.csv ...
# Loading rlEstabComissaoOutro202503.csv ...
# Loading rlEstabComplementar202503.csv ...
# Loading rlEstabEndCompl202503.csv ...
# Loading rlEstabEqpEmbarcacao202503.csv ...
# Loading rlEstabEqpUnidApoio202503.csv ...
# Loading rlEstabEquipamento202503.csv ...
# Loading rlEstabEquipeMun202503.csv ...
# Loading rlEstabEquipeProf202503.csv ...
# Loading rlEstabInstFisiAssist202503.csv ...
# Loading rlEstabOrgParc202503.csv ...
# Loading rlEstabPoloAldeia202503.csv ...
# Loading rlEstabProfComissao202503.csv ...
# Loading rlEstabProgFundo202503.csv ...
# Loading rlEstabRegimeRes202503.csv ...
# Loading rlEstabRepresentante202503.csv ...
# Loading rlEstabSamu202503.csv ...
# Loading rlEstabServClass202503.csv ...
# Loading rlEstabServicoApoio202503.csv ...
# Loading rlEstabSipac202503.csv ...
# Loading rlEstabSubTipo202503.csv ...
# Loading rlEstabTeleCnes202503.csv ...
# Loading rlEstabUnidAcolhim202503.csv ...
# Loading rlMunAtenPsico202503.csv ...
# Loading rlMunRegimeRes202503.csv ...
# Loading rlMunUnidAcolhim202503.csv ...
# Loading rlNasfEsf202503.csv ...
# Loading rlTipoEstabAtividade202503.csv ...
# Loading tbAldeia202503.csv ...
# Loading tbArea202503.csv ...
# Loading tbAtendimentoPrestado202503.csv ...
# Loading tbAtividade202503.csv ...
# Loading tbAtividadeEnsino202503.csv ...
# Loading tbAtividadeProfissional202503.csv ...
# Loading tbAtributo202503.csv ...
# Loading tbAvaliacao202503.csv ...
# Loading tbBanco202503.csv ...
# Loading tbCargaHorariaSus202503.csv ...
# Loading tbClassificacaoAval202503.csv ...
# Loading tbClassificacaoServico202503.csv ...
# Loading tbColetaSeletivaRejeito202503.csv ...
# Loading tbComissaoOutro202503.csv ...
# Loading tbConselhoClasse202503.csv ...
# Loading tbConvenio202503.csv ...
# Loading tbDadosProfissionalSus202503.csv ...
# Loading tbDialise202503.csv ...
# Loading tbDsei202503.csv ...
# Loading tbEquipamento202503.csv ...
# Loading tbEquipe202503.csv ...
# Loading tbEquipeAtendCompl202503.csv ...
# Loading tbEquipeChDifer202503.csv ...
# Loading tbEstabAtivSecundaria202503.csv ...
# Loading tbEstabContrato202503.csv ...
# Loading tbEstabHorarioAtend202503.csv ...
# Loading tbEstabelecimento202503.csv ...
# Loading tbEstado202503.csv ...
# Loading tbEtnia202503.csv ...
# Loading tbFluxoDadosClientela202503.csv ...
# Loading tbGestao202503.csv ...
# Loading tbGrupoAtividade202503.csv ...
# Loading tbGrupoEquipe202503.csv ...
# Loading tbHemoterapia202503.csv ...
# Loading tbIncentivos202503.csv ...
# Loading tbInstalFisicaParaAssist202503.csv ...
# Loading tbInstituicaoAvaliadora202503.csv ...
# Loading tbLeito202503.csv ...
# Loading tbMantenedora202503.csv ...
# Loading tbModVinculo202503.csv ...
# Loading tbMotivoDesativEquipe202503.csv ...
# Loading tbMotivoDesativacao202503.csv ...
# Loading tbMunicipio202503.csv ...
# Loading tbNaturezaJuridica202503.csv ...
# Loading tbOrgaoEmissor202503.csv ...
# Loading tbPoloBase202503.csv ...
# Loading tbProfResidencia202503.csv ...
# Loading tbQuimioRadio202503.csv ...
# Loading tbResidenciaMed202503.csv ...
# Loading tbSegmento202503.csv ...
# Loading tbServicoApoio202503.csv ...
# Loading tbServicoEspecializado202503.csv ...
# Loading tbServicoReferenciado202503.csv ...
# Loading tbSubGruposHabilitacao202503.csv ...
# Loading tbSubTipo202503.csv ...
# Loading tbSubTipoEquipe202503.csv ...
# Loading tbSubTpModVinculo202503.csv ...
# Loading tbSubtipoInstalacao202503.csv ...
# Loading tbTipoAbrangencia202503.csv ...
# Loading tbTipoCertidao202503.csv ...
# Loading tbTipoCgDifer202503.csv ...
# Loading tbTipoEqSubTipo202503.csv ...
# Loading tbTipoEquipamento202503.csv ...
# Loading tbTipoEquipe202503.csv ...
# Loading tbTipoEscolaridade202503.csv ...
# Loading tbTipoEstabelecimento202503.csv ...
# Loading tbTipoInstalacaoFisica202503.csv ...
# Loading tbTipoServicoReferenciado202503.csv ...
# Loading tbTipoUnidade202503.csv ...
# Loading tbTpModVinculo202503.csv ...
# Loading tbTurnoAtendimento202503.csv ...
#                            file_name sep encoding  load_time_sec  num_rows  \
# 0        rlAdmGerenciaCnes202503.csv   ,  latin-1         0.0121      4594
# 1   rlAtividadeObrigatoria202503.csv   ,    utf-8         0.0007        14
# 2            rlCooperativa202503.csv   ,    utf-8         0.0029      2308
# 3           rlEquipeAldeia202503.csv   ,    utf-8         0.0007       300
# 4          rlEquipeNasfEsf202503.csv   ;  latin-1         0.0909     86467
# 5         rlEstabAtenPsico202503.csv   ,  latin-1         0.0013      1373
# 6    rlEstabAtendPrestConv202503.csv   ,  latin-1         0.5452   1004536
# 7         rlEstabAvaliacao202503.csv   ,  latin-1         0.0014      1737
# 8        rlEstabCentralReg202503.csv   ,  latin-1         0.0049      3210
# 9  rlEstabColetaSelRejeito202503.csv   ,  latin-1         0.4640    851518
#
#    num_columns  memory_mb                                            columns
# 0            5      0.712  NU_CNPJ_ADM;"CO_UNIDADE";"TO_CHAR(DT_VIGENCIA_...
# 1            1      0.001  CO_TIPO_ESTABELECIMENTO;"CO_ATIVIDADE_OBRIGATO...
# 2            3      0.270  CO_UNIDADE;"CO_COOPERATIVA";"CO_CBO";"CO_USUAR...
# 3            3      0.039  CO_MUNICIPIO;"CO_AREA";"CO_SEQ_EQUIPE";"CO_ALD...
# 4           17     34.202  CO_MUNICIPIO, CO_AREA, SEQ_EQUIPE, CO_MUNICIPI...
# 5            3      0.229  CO_UNIDADE;"TP_ESTRUTURA";"ST_PARCERIA_ONG";"N...
# 6            3    108.831  CO_UNIDADE;"CO_ATENDIMENTO_PRESTADO";"CO_CONVE...
# 7            4      0.230  CO_UNIDADE;"CO_AVALIACAO";"CO_CLASSIFICACAO";"...
# 8            3      0.943  CO_UNIDADE;"CO_SEQ_CENTRAL";"NO_CENTRAL";"CO_S...
# 9            3     88.224  CO_UNIDADE;"CO_COLETA_REJEITO";"TO_CHAR(DT_ATU...

# %%
summary_df.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/q4/r947g97d1mdblr_m7b44wpfc0000gp/T/ipykernel_69026/1020582454.py in ?()
# ----> 1 summary_df.orderBy("num_rows", "desc").head()
#
# ~/pessoal/cnes-project-analysis/.venv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'orderBy'

# %%
# Save per-column missingness for each file

miss_rows = []
for csv_path in csv_files:
    df, meta = try_read_csv(csv_path)
    miss_pct = (df.isna().mean() * 100).round(2)
    for col, pct in miss_pct.items():
        miss_rows.append({
            "file_name": csv_path.name,
            "column_name": col,
            "missing_pct": pct,
            "sep": meta["sep"],
            "encoding": meta["encoding"],
        })

miss_df = pd.DataFrame(miss_rows)
miss_path = OUTPUT_DIR / "cnes_202503_missingness_by_column.csv"
miss_df.to_csv(miss_path, index=False)
miss_df.head(20)
# Out:
#                            file_name  \
# 0        rlAdmGerenciaCnes202503.csv
# 1        rlAdmGerenciaCnes202503.csv
# 2        rlAdmGerenciaCnes202503.csv
# 3        rlAdmGerenciaCnes202503.csv
# 4        rlAdmGerenciaCnes202503.csv
# 5   rlAtividadeObrigatoria202503.csv
# 6            rlCooperativa202503.csv
# 7            rlCooperativa202503.csv
# 8            rlCooperativa202503.csv
# 9           rlEquipeAldeia202503.csv
# 10          rlEquipeAldeia202503.csv
# 11          rlEquipeAldeia202503.csv
# 12         rlEquipeNasfEsf202503.csv
# 13         rlEquipeNasfEsf202503.csv
# 14         rlEquipeNasfEsf202503.csv
# 15         rlEquipeNasfEsf202503.csv
# 16         rlEquipeNasfEsf202503.csv
# 17         rlEquipeNasfEsf202503.csv
# 18         rlEquipeNasfEsf202503.csv
# 19         rlEquipeNasfEsf202503.csv
#
#                                           column_name  missing_pct sep  \
# 0   NU_CNPJ_ADM;"CO_UNIDADE";"TO_CHAR(DT_VIGENCIA_...          0.0   ,
# 1           'DD/MM/YYYY')";"TO_CHAR(DT_VIGENCIA_FINAL        100.0   ,
# 2              'DD/MM/YYYY')";"TO_CHAR(DT_ATUALIZACAO        100.0   ,
# 3   'DD/MM/YYYY')";"CO_USUARIO";"TO_CHAR(DT_ATUALI...        100.0   ,
# 4                                      'DD/MM/YYYY')"        100.0   ,
# 5   CO_TIPO_ESTABELECIMENTO;"CO_ATIVIDADE_OBRIGATO...          0.0   ,
# 6   CO_UNIDADE;"CO_COOPERATIVA";"CO_CBO";"CO_USUAR...          0.0   ,
# 7       'DD/MM/YYYY')";"TO_CHAR(DT_ATUALIZACAO_ORIGEM        100.0   ,
# 8                                      'DD/MM/YYYY')"        100.0   ,
# 9   CO_MUNICIPIO;"CO_AREA";"CO_SEQ_EQUIPE";"CO_ALD...          0.0   ,
# 10  'DD/MM/YYYY')";"CO_USUARIO";"TO_CHAR(DT_ATUALI...        100.0   ,
# 11                                     'DD/MM/YYYY')"        100.0   ,
# 12                                       CO_MUNICIPIO          0.0   ;
# 13                                            CO_AREA          0.0   ;
# 14                                         SEQ_EQUIPE          0.0   ;
# 15                                   CO_MUNICIPIO_ESF          0.0   ;
# 16                                        CO_AREA_ESF          0.0   ;
# 17                                     SEQ_EQUIPE_ESF          0.0   ;
# 18                                      NU_SEQUENCIAL          0.0   ;
# 19                                         CO_UNIDADE          0.0   ;
#
#    encoding
# 0   latin-1
# 1   latin-1
# 2   latin-1
# 3   latin-1
# 4   latin-1
# 5     utf-8
# 6     utf-8
# 7     utf-8
# 8     utf-8
# 9     utf-8
# 10    utf-8
# 11    utf-8
# 12  latin-1
# 13  latin-1
# 14  latin-1
# 15  latin-1
# 16  latin-1
# 17  latin-1
# 18  latin-1
# 19  latin-1
